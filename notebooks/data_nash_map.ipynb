# %%
import pandas as pd
import geopandas as gdp
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
# %matplotlib inline

# %%
zipcodes = gdp.read_file('../data/zipcodes.geojson')

# %%
zipcodes.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   zip             56 non-null     object
#  1   objectid        56 non-null     object
#  2   po_name         56 non-null     object
#  3   shape_stlength  56 non-null     object
#  4   shape_starea    56 non-null     object
#  5   geometry        56 non-null     geometry
# dtypes: geometry(1), object(5)
# memory usage: 2.8+ KB

# %%
zipcodes.plot()
# Out:
# <Axes: >

# %%
metro_parks= gdp.read_file('../data/metro_park_boundary.geojson')

# %%
metro_parks.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   acres       287 non-null    object
#  1   name        183 non-null    object
#  2   year_estab  287 non-null    object
#  3   common_nam  287 non-null    object
#  4   status      287 non-null    object
#  5   address     283 non-null    object
#  6   lon         287 non-null    object
#  7   lat         287 non-null    object
#  8   descriptio  103 non-null    object
#  9   geometry    287 non-null    geometry
# dtypes: geometry(1), object(9)
# memory usage: 22.5+ KB

# %%
metro_parks.head()
# Out:
#       acres                  name year_estab     common_nam status  \
# 0     69.86    Harpeth River Park       1988  Harpeth River   PARK
# 1      9.88    Harpeth Knoll Park       1972  Harpeth Knoll   PARK
# 2     17.14         Bellevue Park       1982    Red Caboose   PARK
# 3    809.59       Bells Bend Park       2007     Bells Bend   PARK
# 4  2168.792  Alvin G. Beaman Park       1996         Beaman   PARK
#
#                    address           lon          lat  \
# 0      7820 Coley Davis Rd   -86.9592214  36.07738249
# 1  708 Goodpasture Terrace  -86.93815537  36.05942777
# 2     656 Colice Jeanne Rd  -86.93354496  36.07159731
# 3    4187 Old Hickory Blvd  -86.92646294  36.15016925
# 4   5911 Old Hickory Blvd.  -86.91984207  36.26075833
#
#                                           descriptio  \
# 0  Harpeth River State Park has much historical a...
# 1  Huge grassy field with playground, and shade s...
# 2  Bellevue Park, known as Red Caboose Park, is p...
# ...

# %%
metro_parks.plot()
# Out:
# <Axes: >

# %%
fountains = gdp.read_file('../data/public_hydration_systems.geojson')

# %%
fountains.head()
# Out:
#                                             name             location dog  \
# 0                          Beaman Water Fountain                 None   Y
# 1             Edwin Nature Center Water Fountain  Restrooms Breezeway   N
# 2  Percy Warner Belle Meade Gates Water Fountain    Belle Meade Gates   Y
# 3                       West Park Water Fountain            Ballfield   N
# 4                   Richland Park Water Fountain           Playground   N
#
#   objectid          lon ada cnt           lat                   feat_type  \
# 0    45921  36.26250456   Y   1  -86.89425346  Fountain/Bottle filler/ADA
# 1    45937  36.06089915   Y   1  -86.90622747           Bottle Filler/ADA
# 2    45964  36.08310102   Y   1  -86.86727566                    ADA Bowl
# 3    45992  36.16179583   N   1  -86.86378994      Single with foot pedal
# 4    46012  36.15139384   N   1  -86.84589094      Single with foot pedal
#
#                      geometry
# 0  POINT (-86.89425 36.26250)
# ...

# %%
fountains
# Out:
#                                                  name  \
# 0                               Beaman Water Fountain
# 1                  Edwin Nature Center Water Fountain
# 2       Percy Warner Belle Meade Gates Water Fountain
# 3                            West Park Water Fountain
# 4                        Richland Park Water Fountain
# ..                                                ...
# 68                             Harpeth River Greenway
# 69                             Harpeth River Greenway
# 70                                      River Landing
# 71                  Ascend Amphiteater Water Fountain
# 72  Stones River - Percy Priest Dog Park Water Fou...
#
#                               location dog objectid           lon ada cnt  \
# 0                                 None   Y    45921   36.26250456   Y   1
# 1                  Restrooms Breezeway   N    45937   36.06089915   Y   1
# 2                    Belle Meade Gates   Y    45964   36.08310102   Y   1
# ...

# %%
type(fountains)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
fountains_in_zip = gdp.sjoin(fountains, zipcodes, predicate = 'within')

# %%
fountains_in_zip.head()
# Out:
#                                              name             location dog  \
# 0                           Beaman Water Fountain                 None   Y
# 1              Edwin Nature Center Water Fountain  Restrooms Breezeway   N
# 2   Percy Warner Belle Meade Gates Water Fountain    Belle Meade Gates   Y
# 29           Edwin Warner Dog Park Water Fountain             Dog Park   Y
# 30         Edwin Warner Concession Water Fountain     WNSL Concessions   N
#
#    objectid          lon ada cnt           lat                   feat_type  \
# 0     45921  36.26250456   Y   1  -86.89425346  Fountain/Bottle filler/ADA
# 1     45937  36.06089915   Y   1  -86.90622747           Bottle Filler/ADA
# 2     45964  36.08310102   Y   1  -86.86727566                    ADA Bowl
# 29    46595  36.05195562   N   1  -86.90162012                    Dog Only
# 30    46597  36.04998346   Y   1   -86.8981744                Standard/ADA
#
#                       geometry  index_right    zip    po_name
# ...

# %%
fountains_in_zip.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/geospatial/lib/python3.10/site-packages/pandas/core/algorithms.py:1596, in safe_sort(values, codes, use_na_sentinel, assume_unique, verify)
#    1595 try:
# -> 1596     sorter = values.argsort()
#    1597     ordered = values.take(sorter)
#
# File ~/anaconda3/envs/geospatial/lib/python3.10/site-packages/pandas/core/arrays/base.py:806, in ExtensionArray.argsort(self, ascending, kind, na_position, **kwargs)
#     804 ascending = nv.validate_argsort_with_ascending(ascending, (), kwargs)
# --> 806 values = self._values_for_argsort()
#     807 return nargsort(
#     808     values,
#     809     kind=kind,
#    (...)
#     812     mask=np.asarray(self.isna()),
#     813 )
#
# File ~/anaconda3/envs/geospatial/lib/python3.10/site-packages/geopandas/array.py:1252, in GeometryArray._values_for_argsort(self)
# ...
